# %%
from get_lineups import get_lineups
from nba_api.stats.endpoints import PlayByPlayV3
from nba_api.stats.endpoints import boxscoretraditionalv2
import pandas as pd
import numpy as np
import re

# %%
# game_id = "0022400501"
# game_id = "0022400062"
game_id = "0022400652"

# %%
TIP_TO_RE = re.compile(r"Tip to ([A-Za-z .'-]+)")
PERIOD_RE = re.compile(r"(Start|End) of (\d)(st|nd|rd|th) (Period|OT).*")

# %%
boxscore = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id).get_data_frames()[0]
if boxscore.empty:
    print('DataFrame is empty')
boxscore['LAST_NAME'] = boxscore.apply(lambda row: row['PLAYER_NAME'].replace(row['NICKNAME'], '').strip(), axis = 1)
player_team_dict = {}
teams = []
for idx, player in boxscore.iterrows():
    if player['MIN'] == None:
        continue

    last_name = player['LAST_NAME']
    team = player['TEAM_ABBREVIATION']
    player_team_dict[last_name] = team

    if team not in teams:
        teams.append(team)

player_team_dict
# Out:
# {'Wagner': 'ORL',
#  'Banchero': 'ORL',
#  'Carter Jr.': 'ORL',
#  'Black': 'ORL',
#  'Caldwell-Pope': 'ORL',
#  'da Silva': 'ORL',
#  'Bitadze': 'ORL',
#  'Isaac': 'ORL',
#  'Anthony': 'ORL',
#  'Highsmith': 'MIA',
#  'Adebayo': 'MIA',
#  'Ware': 'MIA',
#  'Robinson': 'MIA',
#  'Herro': 'MIA',
#  'Jović': 'MIA',
#  'Rozier': 'MIA',
#  'Larsson': 'MIA',
#  'Love': 'MIA'}

# %%
def other_team(team, teams = teams):
    return teams[0] if team == teams[1] else teams[1]

# %%
pbp = PlayByPlayV3(game_id=game_id).get_data_frames()[0]

# %%
team_tricode_dictionary = {}
team_tricodes = pbp['teamTricode'].unique()[1:]
team_tricode_dictionary[team_tricodes[0]] = pbp[pbp['teamTricode'] == team_tricodes[0]]['location'].unique()[0]
team_tricode_dictionary[team_tricodes[1]] = pbp[pbp['teamTricode'] == team_tricodes[1]]['location'].unique()[0]
team_tricode_dictionary
# Out:
# {'MIA': 'h', 'ORL': 'v'}

# %%
pbp['time_in_period'] = (12 * 60 - (60 * pbp['clock'].str[2:4].astype(int) + pbp['clock'].str[5:10].astype(float))) * 10
pbp['period'] = pbp['period'].astype(int)
regular_periods = (pbp['period'].clip(upper=4) - 1)
ot_periods = (pbp['period'] - 5).clip(lower=0)
pbp['time'] = regular_periods * 60 * 12 * 10 + ot_periods * 60 * 5 * 10 + pbp['time_in_period']
pbp[['scoreHome', 'scoreAway']] = pbp[['scoreHome', 'scoreAway']].replace('', np.nan)
pbp[['scoreHome', 'scoreAway']] = pbp[['scoreHome', 'scoreAway']].ffill()

# %%
plays = pbp[['actionNumber', 'teamId', 'scoreHome', 'scoreAway', 'description', 'actionType', 'subType', 'time', 'location']].copy()
plays['newPossession'] = False
plays['possession'] = None

# %%
for idx, row in plays.iterrows():
    actionType = row['actionType']
    subType = row['subType']
    actionNumber = row['actionNumber']
    location = row['location']
    description = row['description']

    if actionType == 'Made Shot':

        next_idx = idx + 1
        while plays.at[next_idx, 'actionNumber'] == actionNumber or (plays.at[next_idx, 'actionType'] in ('Substitution', 'Timeout')):
            next_idx += 1
        next_play = plays.loc[next_idx]

        # And 1 play
        if (next_play['actionType'] == 'Foul') and (next_play['subType'] == 'Shooting') and (next_play['location'] != location): # in ('Shooting', 'Flagrant')
            continue

        # Regular basket made
        plays.at[idx + 1, 'newPossession'] = True

    elif actionType == 'Turnover':
        plays.at[idx + 1, 'newPossession'] = True

    elif actionType == 'Missed Shot':

        next_idx = idx + 1
        while plays.at[next_idx, 'actionNumber'] == actionNumber:
            next_idx += 1
        next_play = plays.loc[next_idx]

        assert next_play['actionType'] == 'Rebound', f"Next play {next_play['description']} (action {next_play['actionNumber']}) (row {idx}) after {row['description']} is not rebound"
        if location != next_play['location']:
            plays.at[next_idx, 'newPossession'] = True

    elif actionType == 'Foul' and subType == 'Transition Take':
        retain_possession_free_throw = True

    elif actionType == 'Free Throw' and subType not in ('Free Throw 1 of 2', 'Free Throw 1 of 3', 'Free Throw 2 of 3', 'Free Throw Technical'):

        next_idx = idx + 1
        while (plays.at[next_idx, 'actionNumber'] == actionNumber) or (plays.at[next_idx, 'actionType'] in ('Substitution', 'Timeout')):
            next_idx += 1
        next_play = plays.loc[next_idx]

        if next_play['actionType'] in ('Foul', 'Violation'):
            if location == next_play['location']:
                plays.at[next_idx, 'newPossession'] = True
        elif next_play['actionType'] == 'period':
            continue
        else:
            if location != next_play['location']:
                plays.at[next_idx, 'newPossession'] = True

    elif actionType == 'Jump Ball':
        last_idx = idx - 1
        while (plays.at[last_idx, 'actionNumber'] == actionNumber) or (plays.at[last_idx, 'actionType'] in ('Substitution', 'Timeout', 'Foul', 'Violation')):
            last_idx -= 1
        last_play = plays.loc[last_idx]

        # Jump ball at new period
        if last_play['actionType'] == 'period':

            # Who got the ball
            m = TIP_TO_RE.search(description)
            assert m, f"No player found in description: {description} (row {idx})"
            player = m.group(1).strip()
            assert player in player_team_dict, f"{player} not found in player_team_dict"
            team = player_team_dict[player]

            plays.at[idx, 'newPossession'] = True
            plays.at[idx, 'possession'] = team

            # Save tipoff winner
            if idx == 1:
                initial_tip = team

        # In game jump ball
        else:

            # Who got the ball
            m = TIP_TO_RE.search(description)
            assert m, f"No player found in description: {description} (row {idx})"
            player = m.group(1).strip()
            assert player in player_team_dict, f"{player} not found in player_team_dict"
            team = player_team_dict[player]
            team_home_or_visitor = team_tricode_dictionary[team]  # team has to be converted to v and h

            # Who had possession of the ball in previous play
            if last_play['actionType'] == 'Rebound':
                last_possession = last_play['location']
            else:
                last_possession = other_team(last_play['location'], teams = ['h', 'v'])

            # Evaluate wether it is a new possession
            if team_home_or_visitor != last_possession:  
                plays.at[idx, 'newPossession'] = True

    elif actionType == 'period':
        if subType == 'start':
            m = PERIOD_RE.search(description)
            assert m, f"No period found in description: {description}"
            period = int(m.group(2))
            quarter_type = m.group(4)

            if period in (2, 3, 4) and quarter_type == 'Period':
                plays.at[idx, 'newPossession'] = True

        # Rewrites any newPossession = True that could be carried over from previous plays
            elif quarter_type == 'OT':
                    plays.at[idx, 'newPossession'] = False
                    
        elif subType == 'end':
            plays.at[idx, 'newPossession'] = False

# %%
for idx, row in plays.iterrows():
    possession_end = row['newPossession']
    actionType = row['actionType']
    subType = row['subType']
    description = row['description']

    if actionType == 'period' and subType == 'start':
        m = PERIOD_RE.search(description)
        assert m, f"No period found in description: {description}"
        period = int(m.group(2))
        quarter_type = m.group(4)

        if quarter_type == 'Period':
            if period in (2, 3):
                plays.at[idx, 'possession'] = other_team(initial_tip)

            if period == 4:
                plays.at[idx, 'possession'] = initial_tip        

    elif actionType == 'Jump Ball' and plays.at[idx - 1, 'actionType'] == 'period':
        m = TIP_TO_RE.search(description)
        assert m, f"No player found in description: {description} (row {idx})"
        player = m.group(1).strip()
        assert player in player_team_dict, f"{player} not found in player_team_dict"
        team = player_team_dict[player]
        plays.at[idx, 'possession'] = team

    elif idx > 1:
        last_possession = plays.at[idx - 1, 'possession']
        if possession_end:
            plays.at[idx, 'possession'] = other_team(last_possession)
        else:
            plays.at[idx, 'possession'] = last_possession

# %%
plays['possessionCount'] = plays['newPossession'].cumsum()

# %%
plays[plays['actionType'] == 'period']
# Out:
#      actionNumber  teamId scoreHome scoreAway  \
# 0               2       0         0         0
# 113           157       0        27        29
# 114           164       0        27        29
# 233           329       0        55        59
# 234           336       0        55        59
# 332           470       0        79        88
# 333           475       0        79        88
# 443           623       0       108       108
# 444           628       0       108       108
# 492           696       0       116       116
# 493           701       0       116       116
# 527           747       0       125       119
#
#                            description actionType subType     time location  \
# 0    Start of 1st Period (7:43 PM EST)     period   start      0.0
# 113    End of 1st Period (8:10 PM EST)     period     end   7200.0
# 114  Start of 2nd Period (8:13 PM EST)     period   start   7200.0
# 233    End of 2nd Period (8:42 PM EST)     period     end  14400.0
# 234  Start of 3rd Period (8:57 PM EST)     period   start  14400.0
# 332    End of 3rd Period (9:23 PM EST)     period     end  21600.0
# 333  Start of 4th Period (9:25 PM EST)     period   start  21600.0
# 443    End of 4th Period (9:56 PM EST)     period     end  28800.0
# 444      Start of 1st OT (9:59 PM EST)     period   start  25800.0
# 492       End of 1st OT (10:13 PM EST)     period     end  28800.0
# 493     Start of 2nd OT (10:15 PM EST)     period   start  28800.0
# 527       End of 2nd OT (10:24 PM EST)     period     end  31800.0
#
#      newPossession possession  possessionCount
# 0            False       None                0
# 113          False        ORL               51
# 114           True        MIA               52
# 233          False        ORL              101
# 234           True        MIA              102
# 332          False        MIA              144
# 333           True        ORL              145
# 443          False        ORL              189
# 444          False       None              189
# 492          False        ORL              208
# 493          False       None              208
# 527          False        MIA              223

# %%
plays.to_csv('playsMIA.csv')

# %%
plays['actionType'].unique()
# Out:
# array(['period', 'Jump Ball', 'Made Shot', 'Turnover', '', 'Missed Shot',
#        'Rebound', 'Foul', 'Free Throw', 'Substitution', 'Timeout',
#        'Instant Replay', 'Violation'], dtype=object)

# %%
pbp.head()
# Out:
#        gameId  actionNumber        clock  period      teamId teamTricode  \
# 0  0022400652             2  PT12M00.00S       1           0
# 1  0022400652             4  PT12M00.00S       1  1610612748         MIA
# 2  0022400652             8  PT11M41.00S       1  1610612753         ORL
# 3  0022400652            10  PT11M16.00S       1  1610612748         MIA
# 4  0022400652            10  PT11M16.00S       1  1610612753         ORL
#
#    personId  playerName    playerNameI  xLegacy  ...  pointsTotal  location  \
# 0         0                                   0  ...            0
# 1   1642276        Ware        K. Ware        0  ...            0         h
# 5                 Kevin Love
# 6                Bam Adebayo
# 7            Duncan Robinson
# 8                Kel'el Ware
# 9   Kentavious Caldwell-Pope
# 10              Nikola Jovic
# 11               Tyler Herro
# 12              Goga Bitadze
# 13               Bam Adebayo
# 14              Franz Wagner
# 15            Paolo Banchero
# 16         Haywood Highsmith
# 17               Kel'el Ware
# 18          Tristan da Silva
# 19              Nikola Jovic
# 20              Cole Anthony
# 21              Terry Rozier
# 22             Pelle Larsson
# 23            Jonathan Isaac
# 24           Duncan Robinson
# 25               Bam Adebayo
# 26  Kentavious Caldwell-Pope
# 27               Tyler Herro
# 28              Franz Wagner
# 29              Goga Bitadze
# 30            Jonathan Isaac
# 31              Goga Bitadze
# 32          Tristan da Silva
# 33            Jonathan Isaac
# 34         Haywood Highsmith
# 35           Duncan Robinson
# 36            Jonathan Isaac
# 37          Tristan da Silva
#
# [38 rows x 22 columns]

# %%
df = pd.merge_asof(lineups, pbp[['scoreHome', 'scoreAway', 'time']], left_on='End_Time', right_on='time', direction='backward')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1395], line 1
# ----> 1 df = pd.merge_asof(lineups, pbp[['scoreHome', 'scoreAway', 'time']], left_on='End_Time', right_on='time', direction='backward')
#
# File c:\Users\svest\Desktop\NBA-Adjusted-Plus-Minus\venv\Lib\site-packages\pandas\core\reshape\merge.py:708, in merge_asof(left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, tolerance, allow_exact_matches, direction)
#     456 """
#     457 Perform a merge by key distance.
#     458
#    (...)    689 4 2016-05-25 13:30:00.048   AAPL   98.00       100     NaN     NaN
#     690 """
#     691 op = _AsOfMerge(
#     692     left,
#     693     right,
#    (...)    706     direction=direction,
#     707 )
# --> 708 return op.get_result()
#
# File c:\Users\svest\Desktop\NBA-Adjusted-Plus-Minus\venv\Lib\site-packages\pandas\core\reshape\merge.py:1927, in _OrderedMerge.get_result(self, copy)
#    1926 def get_result(self, copy: bool | None = True) -> DataFrame:
# -> 1927     join_index, left_indexer, right_indexer = self._get_join_info()
#    1929     left_join_indexer: npt.NDArray[np.intp] | None
#    1930     right_join_indexer: npt.NDArray[np.intp] | None
#
# File c:\Users\svest\Desktop\NBA-Adjusted-Plus-Minus\venv\Lib\site-packages\pandas\core\reshape\merge.py:1152, in _MergeOperation._get_join_info(self)
#    1148     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1149         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1150     )
#    1151 else:
# -> 1152     (left_indexer, right_indexer) = self._get_join_indexers()
#    1154     if self.right_index:
#    1155         if len(self.left) > 0:
#
# File c:\Users\svest\Desktop\NBA-Adjusted-Plus-Minus\venv\Lib\site-packages\pandas\core\reshape\merge.py:2240, in _AsOfMerge._get_join_indexers(self)
#    2238 # initial type conversion as needed
#    2239 left_values = self._convert_values_for_libjoin(left_values, "left")
# -> 2240 right_values = self._convert_values_for_libjoin(right_values, "right")
#    2242 # a "by" parameter requires special handling
#    2243 if self.left_by is not None:
#    2244     # remove 'on' parameter from values if one existed
#
# File c:\Users\svest\Desktop\NBA-Adjusted-Plus-Minus\venv\Lib\site-packages\pandas\core\reshape\merge.py:2183, in _AsOfMerge._convert_values_for_libjoin(self, values, side)
#    2181     if isna(values).any():
#    2182         raise ValueError(f"Merge keys contain null values on {side} side")
# -> 2183     raise ValueError(f"{side} keys must be sorted")
#    2185 if isinstance(values, ArrowExtensionArray):
#    2186     values = values._maybe_convert_datelike_array()
#
# ValueError: right keys must be sorted

# %%
df
# Out:
#     Start_Time  End_Time Player_1_Home_ID        Player_1_Home_Name  \
# 0          0.0    3160.0           201144               Mike Conley
# 1       3160.0    3540.0           201144               Mike Conley
# 2       3540.0    4110.0           203497               Rudy Gobert
# 3       4110.0    5370.0           203497               Rudy Gobert
# 4       5370.0    5880.0           203497               Rudy Gobert
# 5       5880.0    6520.0          1630162           Anthony Edwards
# 6       6520.0    7200.0          1630162           Anthony Edwards
# 7       7200.0    9270.0          1628978          Donte DiVincenzo
# 8       9270.0    9860.0          1628978          Donte DiVincenzo
# 9       9860.0    9960.0          1628978          Donte DiVincenzo
# 10      9960.0   10320.0          1628978          Donte DiVincenzo
# 11     10320.0   11610.0          1628978          Donte DiVincenzo
# 12     11610.0   12000.0          1629060             Rui Hachimura
# 13     12000.0   13610.0          1642261             Dalton Knecht
# 14     13610.0   14400.0           203497               Rudy Gobert
# 15     14400.0   16540.0           203497               Rudy Gobert
# 16     16540.0   17410.0           203497               Rudy Gobert
# 17     17410.0   17830.0           203497               Rudy Gobert
# 18     17830.0   18310.0           203497               Rudy Gobert
# 19     18310.0   19030.0           203497               Rudy Gobert
# 20     19030.0   19430.0           203497               Rudy Gobert
# 21     19430.0   19800.0           203497               Rudy Gobert
# 22     19800.0   21600.0           203076             Anthony Davis
# 23     21600.0   22490.0          1629638  Nickeil Alexander-Walker
# 24     22490.0   23000.0          1629638  Nickeil Alexander-Walker
# 25     23000.0   23640.0          1629675                  Naz Reid
# 26     23640.0   24510.0          1629675                  Naz Reid
# 27     24510.0   25780.0          1629675                  Naz Reid
# 28     25780.0   27500.0          1626156          D'Angelo Russell
# 29     27500.0   28530.0          1626156          D'Angelo Russell
# 30     28530.0   28800.0          1626156          D'Angelo Russell
#
#    Player_2_Home_ID Player_2_Home_Name Player_3_Home_ID  \
# 0            203497        Rudy Gobert           203944
# 1            203497        Rudy Gobert           203944
# 2           1630162    Anthony Edwards          1630183
# 3           1630162    Anthony Edwards          1630183
# 4           1630162    Anthony Edwards           203076
# 5            203076      Anthony Davis          1631108
# 6           1631108       Max Christie          1628978
# 7           1629675           Naz Reid          1629638
# 8           1629675           Naz Reid             2544
# 9           1629675           Naz Reid          1626156
# 10          1629675           Naz Reid          1626156
# 11          1629675           Naz Reid          1629060
# 12          1642261      Dalton Knecht           203497
# 13           203497        Rudy Gobert           203076
# 14           203076      Anthony Davis          1630559
# 15           203076      Anthony Davis          1630559
# 16           203076      Anthony Davis          1630559
# 17           203076      Anthony Davis          1630559
# 18           203076      Anthony Davis          1630559
# 19           203076      Anthony Davis          1630559
# 20           203076      Anthony Davis          1630559
# 21           203076      Anthony Davis          1630559
# 22          1630162    Anthony Edwards          1628978
# 23          1629675           Naz Reid          1642261
# 24          1629675           Naz Reid             2544
# 25             2544       LeBron James          1629637
# 26             2544       LeBron James          1629637
# 27          1626156   D'Angelo Russell          1629060
# 28          1630559      Austin Reaves          1628978
# 29          1630559      Austin Reaves          1628978
# 30          1630559      Austin Reaves          1628978
#
#           Player_3_Home_Name Player_4_Home_ID        Player_4_Home_Name  ...  \
# 0              Julius Randle          1630162           Anthony Edwards  ...
# 1              Julius Randle          1630162           Anthony Edwards  ...
# 2            Jaden McDaniels           203076             Anthony Davis  ...
# 3            Jaden McDaniels           203076             Anthony Davis  ...
# 4              Anthony Davis          1631108              Max Christie  ...
# 5               Max Christie          1628978          Donte DiVincenzo  ...
# 6           Donte DiVincenzo          1629675                  Naz Reid  ...
# 7   Nickeil Alexander-Walker             2544              LeBron James  ...
# 8               LeBron James          1629637              Jaxson Hayes  ...
# 9           D'Angelo Russell           201144               Mike Conley  ...
# 10          D'Angelo Russell           201144               Mike Conley  ...
# 11             Rui Hachimura          1642261             Dalton Knecht  ...
# 12               Rudy Gobert           203076             Anthony Davis  ...
# 13             Anthony Davis          1630559             Austin Reaves  ...
# 14             Austin Reaves          1630162           Anthony Edwards  ...
# 15             Austin Reaves          1630162           Anthony Edwards  ...
# 16             Austin Reaves          1630162           Anthony Edwards  ...
# 17             Austin Reaves          1630162           Anthony Edwards  ...
# 18             Austin Reaves          1630162           Anthony Edwards  ...
# 19             Austin Reaves          1630162           Anthony Edwards  ...
# 20             Austin Reaves          1630162           Anthony Edwards  ...
# 21             Austin Reaves          1630162           Anthony Edwards  ...
# 22          Donte DiVincenzo          1629638  Nickeil Alexander-Walker  ...
# 23             Dalton Knecht             2544              LeBron James  ...
# 24              LeBron James          1629637              Jaxson Hayes  ...
# 25              Jaxson Hayes           201144               Mike Conley  ...
# 26              Jaxson Hayes          1626156          D'Angelo Russell  ...
# 27             Rui Hachimura          1630559             Austin Reaves  ...
# 28          Donte DiVincenzo          1630162           Anthony Edwards  ...
# 29          Donte DiVincenzo          1630162           Anthony Edwards  ...
# 30          Donte DiVincenzo          1630162           Anthony Edwards  ...
#
#           Player_2_Away_Name Player_3_Away_ID        Player_3_Away_Name  \
# 0              Anthony Davis          1626156          D'Angelo Russell
# 1           D'Angelo Russell          1629060             Rui Hachimura
# 2              Austin Reaves          1631108              Max Christie
# 3               Max Christie          1628978          Donte DiVincenzo
# 4               Gabe Vincent          1629638  Nickeil Alexander-Walker
# 5   Nickeil Alexander-Walker             2544              LeBron James
# 6               LeBron James          1629637              Jaxson Hayes
# 7           D'Angelo Russell           201144               Mike Conley
# 8              Rui Hachimura          1642261             Dalton Knecht
# 9                Rudy Gobert          1630183           Jaden McDaniels
# 10               Rudy Gobert           203076             Anthony Davis
# 11             Austin Reaves          1630162           Anthony Edwards
# 12                Joe Ingles          1629216              Gabe Vincent
# 13             Julius Randle          1629638  Nickeil Alexander-Walker
# 14  Nickeil Alexander-Walker             2544              LeBron James
# 15          D'Angelo Russell           201144               Mike Conley
# 16          D'Angelo Russell           201144               Mike Conley
# 17               Mike Conley          1629060             Rui Hachimura
# 18             Rui Hachimura          1628978          Donte DiVincenzo
# 19          Donte DiVincenzo          1631108              Max Christie
# 20              Max Christie          1629638  Nickeil Alexander-Walker
# 21  Nickeil Alexander-Walker          1629675                  Naz Reid
# 22             Dalton Knecht           203944             Julius Randle
# 23               Rudy Gobert          1630183           Jaden McDaniels
# 24           Jaden McDaniels          1626156          D'Angelo Russell
# 25             Rui Hachimura          1630559             Austin Reaves
# 26          Donte DiVincenzo          1630162           Anthony Edwards
# 27             Julius Randle          1629638  Nickeil Alexander-Walker
# 28             Anthony Davis          1629216              Gabe Vincent
# 29             Anthony Davis           203497               Rudy Gobert
# 30             Anthony Davis             2544              LeBron James
#
#    Player_4_Away_ID        Player_4_Away_Name Player_5_Away_ID  \
# 0           1629060             Rui Hachimura          1630559
# 1           1630559             Austin Reaves          1631108
# 2           1628978          Donte DiVincenzo          1629675
# 3           1629675                  Naz Reid          1629216
# 4              2544              LeBron James          1629637
# 5           1629637              Jaxson Hayes           203944
# 6            203944             Julius Randle          1626156
# 7           1629060             Rui Hachimura          1642261
# 8            203497               Rudy Gobert          1630183
# 9            203076             Anthony Davis          1630559
# 10          1630559             Austin Reaves          1630162
# 11           204060                Joe Ingles          1629216
# 12           203944             Julius Randle          1629638
# 13             2544              LeBron James          1642355
# 14          1626156          D'Angelo Russell          1631108
# 15          1630183           Jaden McDaniels          1629060
# 16          1629060             Rui Hachimura          1628978
# 17          1628978          Donte DiVincenzo          1631108
# 18          1631108              Max Christie          1629638
# 19          1629638  Nickeil Alexander-Walker          1629675
# 20          1629675                  Naz Reid          1629216
# 21          1629216              Gabe Vincent          1642261
# 22             2544              LeBron James          1629637
# 23          1626156          D'Angelo Russell          1629060
# 24          1629060             Rui Hachimura          1630559
# 25          1628978          Donte DiVincenzo          1630162
# 26           203944             Julius Randle          1629638
# 27           203076             Anthony Davis          1629216
# 28           203497               Rudy Gobert             2544
# 29             2544              LeBron James          1629060
# 30          1629060             Rui Hachimura          1629675
#
#           Player_5_Away_Name scoreHome scoreAway     time
# 0              Austin Reaves        11         7   3160.0
# 1               Max Christie        13         7   3540.0
# 2                   Naz Reid        16        10   4110.0
# 3               Gabe Vincent        18        13   5370.0
# 4               Jaxson Hayes        20        15   5880.0
# 5              Julius Randle        20        18   6520.0
# 6           D'Angelo Russell        22        23   7200.0
# 7              Dalton Knecht        34        27   9270.0
# 8            Jaden McDaniels        37        29   9860.0
# 9              Austin Reaves        39        29   9960.0
# 10           Anthony Edwards        43        29  10320.0
# 11              Gabe Vincent        49        32  11610.0
# 12  Nickeil Alexander-Walker        51        35  12000.0
# 13              Bronny James        53        42  13610.0
# 14              Max Christie        55        42  14400.0
# 15             Rui Hachimura        64        47  16540.0
# 16          Donte DiVincenzo        64        53  17410.0
# 17              Max Christie        66        54  17830.0
# 18  Nickeil Alexander-Walker        68        54  18310.0
# 19                  Naz Reid        70        61  19030.0
# 20              Gabe Vincent        72        63  19430.0
# 21             Dalton Knecht        77        65  19800.0
# 22              Jaxson Hayes        82        74  21600.0
# 23             Rui Hachimura        85        81  22490.0
# 24             Austin Reaves        85        81  23000.0
# 25           Anthony Edwards        91        81  23640.0
# 26  Nickeil Alexander-Walker        92        84  24510.0
# 27              Gabe Vincent        99        88  25780.0
# 28              LeBron James       107        95  27500.0
# 29             Rui Hachimura       110       101  28530.0
# 30                  Naz Reid       110       103  28800.0
#
# [31 rows x 25 columns]
